# %% [markdown]
# # Theory Ques.

# %% [markdown]
# Q1 What is hypothesis testing in statistics

# %% [markdown]
# Hypothesis Testing is a fundamental statistical method used to make decisions or inferences about a population based on a sample of data. It helps determine whether there is enough evidence in a sample to support or reject a specific assumption (called a hypothesis) about a population parameter.

# %% [markdown]
# Q2 What is the null hypothesis, and how does it differ from the alternative hypothesis

# %% [markdown]
# Null Hypothesis (H₀):
#
# It is the default assumption that there is no effect, no difference, or no relationship in the population.
#
# Example: "The mean height of students is 170 cm." (H₀: μ = 170)
#
# Alternative Hypothesis (H₁ or Ha):
#
# It contradicts the null and proposes that there is an effect, difference, or relationship.
#
# Example: "The mean height is not 170 cm." (H₁: μ ≠ 170)
#
# Difference:
#
# H₀ assumes the status quo; H₁ challenges it.
#
# Hypothesis testing determines whether to reject H₀ in favor of H₁.

# %% [markdown]
# Q3 What is the significance level in hypothesis testing, and why is it important?

# %% [markdown]
# Significance Level (α): The probability of rejecting the null hypothesis when it is actually true (Type I error).
#
# Common values: 0.05, 0.01, or 0.10
#
# Importance:
#
# Sets the threshold for deciding whether results are statistically significant.
#
# Helps control the risk of false positives.

# %% [markdown]
# Q4 What does a P-value represent in hypothesis testing ?

# %% [markdown]
# The P-value is the probability of obtaining a test statistic as extreme as the one observed, assuming the null hypothesis is true.
#
# It quantifies how much evidence we have against H₀.

# %% [markdown]
# Q5 How do you interpret the P-value in hypothesis testing ?

# %% [markdown]
# If P ≤ α → Reject the null hypothesis → Strong evidence against H₀
#
# If P > α → Fail to reject H₀ → Not enough evidence to reject H₀
#
# Example:
#
# P-value = 0.03, α = 0.05 → Reject H₀ (statistically significant)

# %% [markdown]
# Q6 What are Type I and Type 2 errors in hypothesis testing ?

# %% [markdown]
# Type I Error (False Positive):
#
# Rejecting H₀ when it is actually true
#
# Probability = α
#
# Type II Error (False Negative):
#
# Failing to reject H₀ when it is actually false
#
# Probability = β

# %% [markdown]
# Q7 What is the difference between a one-tailed and a two-tailed test in hypothesis testing ?

# %% [markdown]
# One-tailed test: Tests for deviation in one direction (e.g., greater than or less than)
#
# Example: H₁: μ > 100
#
# Two-tailed test: Tests for deviation in both directions (e.g., not equal)
#
# Example: H₁: μ ≠ 100

# %% [markdown]
# Q8 What is the Z-test, and when is it used in hypothesis testing ?

# %% [markdown]
# A Z-test is used to determine whether there is a significant difference between sample and population means when:
#
# The population standard deviation is known
#
# The sample size is large (n > 30)
#
# Example: Testing whether average income of a city is ₹50,000.

# %% [markdown]
# Q9 How do you calculate the Z-score, and what does it represent in hypothesis testing ?

# %% [markdown]
# Z-score formula:
#
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# /
# 𝑛
# Z=
# σ/
# n
# ​
#
# X
# ˉ
#  −μ
# ​
#
# 𝑋
# ˉ
# X
# ˉ
#   = sample mean
#
# 𝜇
# μ = population mean
#
# 𝜎
# σ = population standard deviation
#
# 𝑛
# n = sample size
#
# Represents: How many standard deviations the sample mean is away from the population mean.

# %% [markdown]
# ![Screenshot%202025-07-12%20112712.png](attachment:Screenshot%202025-07-12%20112712.png)

# %% [markdown]
# Q10 What is the T-distribution, and when should it be used instead of the normal distribution ?

# %% [markdown]
# The T-distribution is used when:
#
# Sample size is small (n < 30)
#
# Population standard deviation is unknown
#
# It is wider than the normal distribution to account for more uncertainty.

# %% [markdown]
# Q11 What is the difference between a Z-test and a T-test ?

# %% [markdown]
# A Z-test is a statistical test used to determine whether there is a significant difference between:
#
# A sample mean and a known population mean
#
# Two proportions, or
#
# Two large sample means
#
# 🔹 Key Features:
# Used when the population standard deviation (σ) is known
#
# Typically applied for large sample sizes (n ≥ 30)
#
# Based on the standard normal distribution (Z-distribution)
#
# T-test
#
# A T-test is a statistical test used to determine whether there is a significant difference between:
#
# A sample mean and a population mean (when σ is unknown)
#
# Two sample means (independent or paired)
#
# 🔹 Key Features:
# Used when the population standard deviation is unknown
#
# Preferred for small samples (n < 30)
#
# Based on the t-distribution, which is wider than the Z-distribution to account for extra uncertainty

# %% [markdown]
# Q12 What is the T-test, and how is it used in hypothesis testing ?

# %% [markdown]
# A T-test is a statistical test used to compare means:
#
# One-sample t-test: Mean of one group vs population
#
# Two-sample t-test: Compare means of two independent groups
#
# Paired t-test: Compare means of same group before and after treatment
#
# Used when population standard deviation is unknown.

# %% [markdown]
# Q13 What is the relationship between Z-test and T-test in hypothesis testing ?

# %% [markdown]
# Both are used to test hypotheses about population means.
#
# Z-test is a special case of the t-test when the population standard deviation is known and sample size is large.

# %% [markdown]
# Q14 What is a confidence interval, and how is it used to interpret statistical results ?

# %% [markdown]
# A confidence interval (CI) gives a range of values within which the true population parameter is expected to fall.
#
# Example: 95% CI = (45, 55) means we are 95% confident that the population mean lies between 45 and 55.
#
# Helps estimate parameters rather than just testing.

# %% [markdown]
# Q15 What is the margin of error, and how does it affect the confidence interval ?

# %% [markdown]
# The margin of error (MoE) is the amount added and subtracted from the sample statistic to create the confidence interval.
#
# Formula:   MoE=Z
# α/2
# ​
#  ×
# n
# ​
#
# σ
# ​
#
# A larger MoE → wider interval → more uncertainty

# %% [markdown]
# ![Screenshot%202025-07-12%20114119.png](attachment:Screenshot%202025-07-12%20114119.png)

# %% [markdown]
# Q16 How is Bayes' Theorem used in statistics, and what is its significance ?

# %% [markdown]
# Bayes' Theorem allows us to update the probability of a hypothesis based on new evidence.
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# Applications:
#
# Spam filtering
#
# Medical diagnosis
#
# Predictive modeling

# %% [markdown]
# ![Screenshot%202025-07-12%20114449.png](attachment:Screenshot%202025-07-12%20114449.png)

# %% [markdown]
# Q17 What is the Chi-square distribution, and when is it used ?

# %% [markdown]
# A Chi-square distribution is used to test hypotheses about categorical variables.
#
# Used in:
#
# Goodness of fit tests
#
# Test of independence
#
# Variance analysis

# %% [markdown]
# Q18 What is the Chi-square goodness of fit test, and how is it applied ?

# %% [markdown]
# Tests whether observed categorical data fit a known distribution.
#
# Formula:
#
# 𝜒
# 2
# =
# ∑
# (
# 𝑂
# 𝑖
# −
# 𝐸
# 𝑖
# )
# 2
# 𝐸
# 𝑖
# χ
# 2
#  =∑
# E
# i
# ​
#
# (O
# i
# ​
#  −E
# i
# ​
#  )
# 2
#
# ​
#
# 𝑂
# 𝑖
# O
# i
# ​
#   = Observed frequency
#
# 𝐸
# 𝑖
# E
# i
# ​
#   = Expected frequency
#
# If χ² is large, reject H₀ → observed frequencies do not match expected.

# %% [markdown]
# ![Screenshot%202025-07-12%20114817.png](attachment:Screenshot%202025-07-12%20114817.png)

# %% [markdown]
# Q19 What is the F-distribution, and when is it used in hypothesis testing ?

# %% [markdown]
# F-distribution is used to compare two variances or multiple means (ANOVA).
#
# Always positive and right-skewed.
#
# Common in F-tests, ANOVA, and regression analysis.

# %% [markdown]
# Q20 What is an ANOVA test, and what are its assumptions ?

# %% [markdown]
# ANOVA (Analysis of Variance) compares the means of 3 or more groups.
#
# Tests if at least one group mean is significantly different.
#
# Assumptions:
#
# Normal distribution
#
# Equal variances (homogeneity)
#
# Independent observations

# %% [markdown]
# Q21 What are the different types of ANOVA tests ?

# %% [markdown]
# One-way ANOVA: One independent variable
#
# Two-way ANOVA: Two independent variables
#
# Repeated Measures ANOVA: Same group measured multiple times

# %% [markdown]
# Q22 What is the F-test, and how does it relate to hypothesis testing ?

# %% [markdown]
# The F-test compares the variances of two populations.
#
# Used in:
#
# Testing variance equality
#
# ANOVA (to compare group means)
#
# Helps determine whether variability between group means is more than within-group variability.

# %% [markdown]
# # Practical Ques.

# %% [markdown]
# Q1 Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
# interpret the results

# %%
import numpy as np
from scipy import stats

# Sample data (example)
sample_data = [52, 49, 50, 51, 53, 48, 54, 47, 50, 49]

# Step 1: Define known values
population_mean = 50     # Known population mean
population_std = 2       # Known population standard deviation (σ)
sample_size = len(sample_data)

# Step 2: Calculate sample mean
sample_mean = np.mean(sample_data)

# Step 3: Compute Z-score using formula:
# Z = (sample_mean - population_mean) / (population_std / sqrt(n))
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Step 4: Calculate P-value (two-tailed test)
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Step 5: Print results
print("Sample Mean:", round(sample_mean, 2))
print("Z-score:", round(z_score, 4))
print("P-value:", round(p_value, 4))

# Step 6: Interpret the results
alpha = 0.05  # Significance level

if p_value < alpha:
    print("Result: Reject the null hypothesis (Significant difference).")
else:
    print("Result: Fail to reject the null hypothesis (No significant difference).")
# Out:
# Sample Mean: 50.3
# Z-score: 0.4743
# P-value: 0.6353
# Result: Fail to reject the null hypothesis (No significant difference).

# %% [markdown]
# Q2 Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python

# %%
import numpy as np
from scipy import stats

# Step 1: Simulate random sample data
np.random.seed(42)  # For reproducibility
sample_size = 50
population_mean = 100       # Known population mean (H0)
population_std = 15         # Known population standard deviation
sample_data = np.random.normal(loc=102, scale=15, size=sample_size)  # Simulated data with mean ≠ 100

# Step 2: Calculate sample mean
sample_mean = np.mean(sample_data)

# Step 3: Perform Z-test
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))  # Two-tailed test

# Step 4: Output results
print("Sample Mean:", round(sample_mean, 2))
print("Z-score:", round(z_score, 4))
print("P-value:", round(p_value, 4))

# Step 5: Interpret the result
alpha = 0.05
if p_value < alpha:
    print("Result: Reject the null hypothesis (significant difference).")
else:
    print("Result: Fail to reject the null hypothesis (no significant difference).")
# Out:
# Sample Mean: 98.62
# Z-score: -0.6515
# P-value: 0.5147
# Result: Fail to reject the null hypothesis (no significant difference).

# %% [markdown]
# Q3 Implement a one-sample Z-test using Python to compare the sample mean with the population mean

# %%
import numpy as np
from scipy import stats

# Step 1: Sample data (you can change this)
sample_data = [68, 70, 72, 71, 69, 73, 68, 72, 70, 74]

# Step 2: Known population parameters
population_mean = 70
population_std = 3  # Known standard deviation (σ)

# Step 3: Calculate sample statistics
sample_mean = np.mean(sample_data)
sample_size = len(sample_data)

# Step 4: Calculate Z-score
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Step 5: Calculate P-value (two-tailed test)
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Step 6: Display results
print("Sample Mean:", round(sample_mean, 2))
print("Z-score:", round(z_score, 4))
print("P-value:", round(p_value, 4))

# Step 7: Interpret the result
alpha = 0.05
if p_value < alpha:
    print("Conclusion: Reject the null hypothesis — significant difference.")
else:
    print("Conclusion: Fail to reject the null hypothesis — no significant difference.")
# Out:
# Sample Mean: 70.7
# Z-score: 0.7379
# P-value: 0.4606
# Conclusion: Fail to reject the null hypothesis — no significant difference.

# %% [markdown]
# Q4 Perform a two-tailed Z-test using Python and visualize the decision region on a plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Sample data (you can customize this)
sample_data = [102, 98, 105, 101, 100, 99, 103, 97, 106, 100]

# Step 2: Known population parameters
population_mean = 100
population_std = 3  # Known σ

# Step 3: Calculate statistics
sample_mean = np.mean(sample_data)
n = len(sample_data)
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(n))
p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test

# Step 4: Z critical value for 95% confidence (α = 0.05)
alpha = 0.05
z_critical = norm.ppf(1 - alpha / 2)

# Step 5: Print Results
print("Sample Mean:", round(sample_mean, 2))
print("Z-score:", round(z_score, 4))
print("P-value:", round(p_value, 4))
if abs(z_score) > z_critical:
    print("Conclusion: Reject the null hypothesis — significant difference.")
else:
    print("Conclusion: Fail to reject the null hypothesis — no significant difference.")

# Step 6: Visualization of the decision regions
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)

plt.figure(figsize=(10, 5))
plt.plot(x, y, label='Standard Normal Distribution')

# Shade rejection regions
plt.fill_between(x, y, where=(x <= -z_critical), color='red', alpha=0.3, label='Rejection Region (Left)')
plt.fill_between(x, y, where=(x >= z_critical), color='red', alpha=0.3, label='Rejection Region (Right)')

# Mark Z-score
plt.axvline(z_score, color='blue', linestyle='--', label=f'Z-score = {z_score:.2f}')

# Mark critical values
plt.axvline(-z_critical, color='black', linestyle=':', label=f'-Z-critical = {-z_critical:.2f}')
plt.axvline(z_critical, color='black', linestyle=':', label=f'Z-critical = {z_critical:.2f}')

plt.title("Two-Tailed Z-Test: Decision Region")
plt.xlabel("Z-value")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Sample Mean: 101.1
# Z-score: 1.1595
# P-value: 0.2463
# Conclusion: Fail to reject the null hypothesis — no significant difference.

# %% [markdown]
# Q5 Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_type1_type2(mu_null=100, mu_alt=105, sigma=10, n=30, alpha=0.05):
    """
    Visualizes Type I and Type II errors for a right-tailed Z-test.

    Parameters:
    - mu_null: Mean under the null hypothesis (H₀)
    - mu_alt: Mean under the alternative hypothesis (H₁)
    - sigma: Population standard deviation
    - n: Sample size
    - alpha: Significance level (default 0.05 for 95% confidence)
    """

    # Step 1: Calculate standard error
    se = sigma / np.sqrt(n)

    # Step 2: Z critical value and critical sample mean for right-tailed test
    z_critical = norm.ppf(1 - alpha)
    x_critical = mu_null + z_critical * se

    # Step 3: Calculate Type II error (β)
    z_beta = (x_critical - mu_alt) / se
    beta = norm.cdf(z_beta)

    # Step 4: Calculate power of the test
    power = 1 - beta

    # Step 5: Plot null and alternative distributions
    x = np.linspace(mu_null - 4*se, mu_alt + 4*se, 1000)
    y_null = norm.pdf(x, mu_null, se)
    y_alt = norm.pdf(x, mu_alt, se)

    plt.figure(figsize=(12, 6))
    plt.plot(x, y_null, label='Null Hypothesis (H₀)', color='blue')
    plt.plot(x, y_alt, label='Alternative Hypothesis (H₁)', color='green')

    # Step 6: Shade rejection region (Type I error)
    plt.fill_between(x, y_null, where=(x > x_critical), color='red', alpha=0.3, label='Type I Error (α)')

    # Step 7: Shade Type II error region
    plt.fill_between(x, y_alt, where=(x < x_critical), color='orange', alpha=0.3, label='Type II Error (β)')

    # Step 8: Critical value line
    plt.axvline(x_critical, color='black', linestyle='--', label=f'Critical Value = {x_critical:.2f}')

    plt.title('Type I and Type II Errors in Hypothesis Testing', fontsize=14)
    plt.xlabel('Sample Mean')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # Step 9: Print interpretation
    print(f"➡️  Critical Value (Sample Mean): {x_critical:.2f}")
    print(f"➡️  Z-critical value: {z_critical:.4f}")
    print(f"⚠️  Type I Error (α): {alpha}")
    print(f"⚠️  Type II Error (β): {beta:.4f}")
    print(f"✅  Power of the Test (1 - β): {power:.4f}")

# Example usage
visualize_type1_type2(mu_null=100, mu_alt=105, sigma=10, n=30, alpha=0.05)
# Out:
# ➡️  Critical Value (Sample Mean): 103.00
# ➡️  Z-critical value: 1.6449
# ⚠️  Type I Error (α): 0.05
# ⚠️  Type II Error (β): 0.1370
# ✅  Power of the Test (1 - β): 0.8630

# %% [markdown]
# Q6 Write a Python program to perform an independent T-test and interpret the results

# %%
import numpy as np
from scipy import stats

# Step 1: Define two independent samples (e.g., test scores of two classes)
group1 = [85, 86, 88, 75, 78, 94, 98, 79, 81, 87]
group2 = [80, 82, 84, 76, 77, 88, 85, 83, 79, 78]

# Step 2: Perform independent two-sample t-test
# Use equal_var=False for Welch's t-test if variances are unequal
t_stat, p_value = stats.ttest_ind(group1, group2, equal_var=True)

# Step 3: Output results
print("Group 1 Mean:", np.mean(group1))
print("Group 2 Mean:", np.mean(group2))
print("T-statistic:", round(t_stat, 4))
print("P-value:", round(p_value, 4))

# Step 4: Interpret results (two-tailed test)
alpha = 0.05
if p_value < alpha:
    print("Conclusion: Reject the null hypothesis — significant difference between the groups.")
else:
    print("Conclusion: Fail to reject the null hypothesis — no significant difference between the groups.")
# Out:
# Group 1 Mean: 85.1
# Group 2 Mean: 81.2
# T-statistic: 1.5124
# P-value: 0.1478
# Conclusion: Fail to reject the null hypothesis — no significant difference between the groups.

# %% [markdown]
# Q7  Perform a paired sample T-test using Python and visualize the comparison results

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Step 1: Define paired data (e.g., scores before and after training for same individuals)
before = [72, 74, 78, 76, 75, 80, 79, 82, 77, 74]
after  = [75, 76, 80, 78, 77, 83, 81, 85, 79, 76]

# Step 2: Perform Paired T-test
t_stat, p_value = stats.ttest_rel(before, after)

# Step 3: Print results
print("Mean (Before):", np.mean(before))
print("Mean (After):", np.mean(after))
print("T-statistic:", round(t_stat, 4))
print("P-value:", round(p_value, 4))

# Step 4: Interpret result
alpha = 0.05
if p_value < alpha:
    print("Conclusion: Reject the null hypothesis — significant difference between before and after.")
else:
    print("Conclusion: Fail to reject the null hypothesis — no significant difference.")

# Step 5: Visualization of paired differences
plt.figure(figsize=(10, 5))
plt.plot(before, label='Before', marker='o', linestyle='-', color='blue')
plt.plot(after, label='After', marker='o', linestyle='-', color='green')
plt.title('Paired Sample Comparison')
plt.xlabel('Subjects')
plt.ylabel('Scores')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Mean (Before): 76.7
# Mean (After): 79.0
# T-statistic: -15.057
# P-value: 0.0
# Conclusion: Reject the null hypothesis — significant difference between before and after.

# %% [markdown]
# Q8 Simulate data and perform both Z-test and T-test, then compare the results using Python

# %%
import numpy as np
from scipy import stats

# Step 1: Simulate sample data
np.random.seed(42)
sample_size = 25
population_mean = 100
population_std = 15  # Known for Z-test
sample_data = np.random.normal(loc=102, scale=15, size=sample_size)

# Step 2: Calculate sample statistics
sample_mean = np.mean(sample_data)
sample_std = np.std(sample_data, ddof=1)  # sample std deviation
se_known = population_std / np.sqrt(sample_size)
se_unknown = sample_std / np.sqrt(sample_size)

# Step 3: Z-test (when population std is known)
z_score = (sample_mean - population_mean) / se_known
p_value_z = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Step 4: T-test (when population std is unknown)
t_score, p_value_t = stats.ttest_1samp(sample_data, population_mean)

# Step 5: Display results
print("=== Sample Summary ===")
print("Sample Mean:", round(sample_mean, 2))
print("Sample Std Dev:", round(sample_std, 2))
print("Sample Size:", sample_size)

print("\n=== Z-Test (σ known) ===")
print("Z-score:", round(z_score, 4))
print("P-value:", round(p_value_z, 4))

print("\n=== T-Test (σ unknown) ===")
print("T-score:", round(t_score, 4))
print("P-value:", round(p_value_t, 4))

# Step 6: Interpret
alpha = 0.05
print("\n=== Interpretation (α = 0.05) ===")
if p_value_z < alpha:
    print("Z-test: Reject null hypothesis → Significant difference.")
else:
    print("Z-test: Fail to reject null hypothesis → No significant difference.")

if p_value_t < alpha:
    print("T-test: Reject null hypothesis → Significant difference.")
else:
    print("T-test: Fail to reject null hypothesis → No significant difference.")
# Out:
# === Sample Summary ===
# Sample Mean: 99.55
# Sample Std Dev: 14.35
# Sample Size: 25
#
# === Z-Test (σ known) ===
# Z-score: -0.1509
# P-value: 0.8801
#
# === T-Test (σ unknown) ===
# T-score: -0.1577
# P-value: 0.876
#
# === Interpretation (α = 0.05) ===
# Z-test: Fail to reject null hypothesis → No significant difference.
# T-test: Fail to reject null hypothesis → No significant difference.

# %% [markdown]
# Q9 Write a Python function to calculate the confidence interval for a sample mean and explain its significance

# %%
import numpy as np
from scipy import stats

def confidence_interval(data, confidence=0.95):
    """
    Calculates the confidence interval for the mean of a sample.
    
    Parameters:
    - data (list or array): The sample data
    - confidence (float): Confidence level (default = 0.95 for 95%)
    
    Returns:
    - (lower_bound, upper_bound): The confidence interval
    """

    data = np.array(data)
    n = len(data)
    mean = np.mean(data)
    sem = stats.sem(data)  # Standard Error of the Mean
    margin = stats.t.ppf((1 + confidence) / 2.0, n - 1) * sem

    lower = mean - margin
    upper = mean + margin

    print(f"Sample Mean: {mean:.2f}")
    print(f"Sample Size: {n}")
    print(f"Confidence Level: {confidence * 100:.1f}%")
    print(f"Confidence Interval: ({lower:.2f}, {upper:.2f})")

    return (lower, upper)

# ✅ Example usage
sample_data = [72, 74, 78, 76, 75, 80, 79, 82, 77, 74]
confidence_interval(sample_data, confidence=0.95)
# Out:
# Sample Mean: 76.70
# Sample Size: 10
# Confidence Level: 95.0%
# Confidence Interval: (74.49, 78.91)
# (74.48739904689384, 78.91260095310616)

# %% [markdown]
# Q10  Write a Python program to calculate the margin of error for a given confidence level using sample data

# %%
import numpy as np
from scipy import stats

def calculate_margin_of_error(data, confidence=0.95):
    """
    Calculate the margin of error for a given confidence level using sample data.
    
    Parameters:
    - data: list or numpy array of sample values
    - confidence: confidence level (default = 0.95 for 95%)
    
    Returns:
    - Margin of Error (MoE)
    """

    data = np.array(data)
    n = len(data)
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)  # sample standard deviation
    standard_error = sample_std / np.sqrt(n)

    # t-critical value for the given confidence level
    t_critical = stats.t.ppf((1 + confidence) / 2, df=n - 1)

    # Margin of Error
    moe = t_critical * standard_error

    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Sample Std Dev: {sample_std:.2f}")
    print(f"Sample Size: {n}")
    print(f"Confidence Level: {confidence * 100:.1f}%")
    print(f"Margin of Error: ±{moe:.2f}")

    return moe

# ✅ Example usage
sample_data = [72, 74, 78, 76, 75, 80, 79, 82, 77, 74]
calculate_margin_of_error(sample_data, confidence=0.95)
# Out:
# Sample Mean: 76.70
# Sample Std Dev: 3.09
# Sample Size: 10
# Confidence Level: 95.0%
# Margin of Error: ±2.21
# 2.212600953106161

# %% [markdown]
# Q11 Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

# %%
def bayes_theorem(prior_A, likelihood_B_given_A, likelihood_B_given_not_A):
    """
    Apply Bayes' Theorem to compute the posterior probability.

    Parameters:
    - prior_A: P(A), prior probability of hypothesis A (e.g., disease)
    - likelihood_B_given_A: P(B|A), likelihood of evidence given A (e.g., test is positive if person has disease)
    - likelihood_B_given_not_A: P(B|¬A), likelihood of evidence given not A (false positive rate)

    Returns:
    - posterior: P(A|B), updated belief in A given evidence B
    """
    prior_not_A = 1 - prior_A
    # Marginal probability of evidence
    evidence = (likelihood_B_given_A * prior_A) + (likelihood_B_given_not_A * prior_not_A)
    
    # Posterior probability
    posterior = (likelihood_B_given_A * prior_A) / evidence
    
    print(f"Posterior Probability (P(A|B)): {posterior:.4f}")
    return posterior

# Example usage
# Disease example
prior_disease = 0.01
likelihood_positive_given_disease = 0.99
likelihood_positive_given_healthy = 0.05

bayes_theorem(prior_disease, likelihood_positive_given_disease, likelihood_positive_given_healthy)
# Out:
# Posterior Probability (P(A|B)): 0.1667
# 0.16666666666666669

# %% [markdown]
# Q12 Perform a Chi-square test for independence between two categorical variables in Python

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Step 1: Create a contingency table (observed frequencies)
# Rows = Gender (Male, Female), Columns = Product Preference (A, B, C)
data = [[30, 10, 20],    # Male
        [25, 15, 30]]    # Female

# Convert to DataFrame for clarity
df = pd.DataFrame(data, columns=["Product A", "Product B", "Product C"], index=["Male", "Female"])

print("Contingency Table:")
print(df)

# Step 2: Perform Chi-Square Test of Independence
chi2, p, dof, expected = chi2_contingency(df)

# Step 3: Display results
print("\nChi-square Statistic:", round(chi2, 4))
print("Degrees of Freedom:", dof)
print("P-value:", round(p, 4))

# Show expected frequencies
print("\nExpected Frequencies:")
print(pd.DataFrame(expected, columns=df.columns, index=df.index))

# Step 4: Interpret the result
alpha = 0.05
if p < alpha:
    print("\nConclusion: Reject the null hypothesis — variables are dependent.")
else:
    print("\nConclusion: Fail to reject the null hypothesis — variables are independent.")
# Out:
# Contingency Table:
#         Product A  Product B  Product C
# Male           30         10         20
# Female         25         15         30
#
# Chi-square Statistic: 2.7013
# Degrees of Freedom: 2
# P-value: 0.2591
#
# Expected Frequencies:
#         Product A  Product B  Product C
# Male    25.384615  11.538462  23.076923
# Female  29.615385  13.461538  26.923077
#
# Conclusion: Fail to reject the null hypothesis — variables are independent.

# %% [markdown]
# Q13 Write a Python program to calculate the expected frequencies for a Chi-square test based on observed
# data

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Step 1: Observed data (contingency table)
observed = np.array([[30, 10, 20],   # Example: Gender vs Product Preference
                     [25, 15, 30]])

# Optional: Make it more readable with labels using a DataFrame
observed_df = pd.DataFrame(observed,
                           index=["Male", "Female"],
                           columns=["Product A", "Product B", "Product C"])

print("Observed Frequencies (Contingency Table):")
print(observed_df)

# Step 2: Calculate expected frequencies using chi2_contingency
chi2, p, dof, expected = chi2_contingency(observed)

# Step 3: Display expected frequencies
expected_df = pd.DataFrame(expected,
                           index=observed_df.index,
                           columns=observed_df.columns)

print("\nExpected Frequencies:")
print(expected_df.round(2))
# Out:
# Observed Frequencies (Contingency Table):
#         Product A  Product B  Product C
# Male           30         10         20
# Female         25         15         30
#
# Expected Frequencies:
#         Product A  Product B  Product C
# Male        25.38      11.54      23.08
# Female      29.62      13.46      26.92

# %% [markdown]
# Q14 Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution

# %%
import numpy as np
from scipy.stats import chisquare

# Step 1: Observed frequencies (e.g., survey responses for 4 categories)
observed = np.array([18, 22, 20, 40])

# Step 2: Expected frequencies
# Example 1: Uniform distribution (equal probabilities)
total = sum(observed)
expected = np.array([total / 4] * 4)

# Step 3: Perform Chi-Square Goodness-of-Fit Test
chi_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

# Step 4: Print Results
print("Observed Frequencies:", observed)
print("Expected Frequencies:", expected.astype(int))
print("Chi-square Statistic:", round(chi_stat, 4))
print("P-value:", round(p_value, 4))

# Step 5: Interpret the result
alpha = 0.05
if p_value < alpha:
    print("Conclusion: Reject the null hypothesis — observed data does not fit the expected distribution.")
else:
    print("Conclusion: Fail to reject the null hypothesis — observed data fits the expected distribution.")
# Out:
# Observed Frequencies: [18 22 20 40]
# Expected Frequencies: [25 25 25 25]
# Chi-square Statistic: 12.32
# P-value: 0.0064
# Conclusion: Reject the null hypothesis — observed data does not fit the expected distribution.

# %% [markdown]
# Q15 Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

def simulate_and_plot_chi_square(df_list, x_max=30):
    """
    Simulate and plot Chi-square distributions for various degrees of freedom.

    Parameters:
    - df_list: List of degrees of freedom (e.g., [1, 2, 5, 10])
    - x_max: Maximum x-value for the plot
    """
    x = np.linspace(0, x_max, 1000)

    plt.figure(figsize=(10, 6))
    for df in df_list:
        y = chi2.pdf(x, df)
        plt.plot(x, y, label=f'df = {df}')
    
    plt.title('Chi-Square Distribution for Various Degrees of Freedom')
    plt.xlabel('Chi-square value')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# ✅ Example usage
simulate_and_plot_chi_square(df_list=[1, 2, 5, 10])

# %% [markdown]
# Q16 Implement an F-test using Python to compare the variances of two random samples

# %%
import numpy as np
from scipy.stats import f

def f_test(sample1, sample2, alpha=0.05):
    """
    Performs an F-test to compare the variances of two samples.
    
    Parameters:
    - sample1: List or array of sample 1
    - sample2: List or array of sample 2
    - alpha: Significance level (default = 0.05)
    
    Returns:
    - Prints F-statistic, p-value, and conclusion
    """
    # Step 1: Sample sizes and variances
    n1, n2 = len(sample1), len(sample2)
    var1, var2 = np.var(sample1, ddof=1), np.var(sample2, ddof=1)

    # Step 2: Compute F-statistic (larger variance on top)
    if var1 > var2:
        f_stat = var1 / var2
        dfn, dfd = n1 - 1, n2 - 1
    else:
        f_stat = var2 / var1
        dfn, dfd = n2 - 1, n1 - 1

    # Step 3: Calculate p-value (two-tailed)
    p_value = 2 * min(f.cdf(f_stat, dfn, dfd), 1 - f.cdf(f_stat, dfn, dfd))

    # Step 4: Results
    print("Sample 1 Variance:", round(var1, 4))
    print("Sample 2 Variance:", round(var2, 4))
    print("F-statistic:", round(f_stat, 4))
    print("Degrees of Freedom:", (dfn, dfd))
    print("P-value:", round(p_value, 4))

    # Step 5: Conclusion
    if p_value < alpha:
        print("Conclusion: Reject H₀ — Variances are significantly different.")
    else:
        print("Conclusion: Fail to reject H₀ — No significant difference in variances.")

# ✅ Example usage
np.random.seed(42)
sample_1 = np.random.normal(loc=50, scale=5, size=30)
sample_2 = np.random.normal(loc=52, scale=10, size=30)

f_test(sample_1, sample_2, alpha=0.05)
# Out:
# Sample 1 Variance: 20.2503
# Sample 2 Variance: 86.6951
# F-statistic: 4.2812
# Degrees of Freedom: (29, 29)
# P-value: 0.0002
# Conclusion: Reject H₀ — Variances are significantly different.

# %% [markdown]
# Q17 Write a Python program to perform an ANOVA test to compare means between multiple groups and
# interpret the results

# %%
import numpy as np
from scipy.stats import f_oneway

# Step 1: Define data for multiple groups (example: test scores of 3 different teaching methods)
group_A = [85, 90, 88, 86, 87]
group_B = [78, 75, 80, 77, 76]
group_C = [92, 94, 89, 91, 95]

# Step 2: Perform one-way ANOVA
f_stat, p_value = f_oneway(group_A, group_B, group_C)

# Step 3: Display results
print("Group A Mean:", np.mean(group_A))
print("Group B Mean:", np.mean(group_B))
print("Group C Mean:", np.mean(group_C))
print("\nF-statistic:", round(f_stat, 4))
print("P-value:", round(p_value, 4))

# Step 4: Interpret the results
alpha = 0.05
if p_value < alpha:
    print("\nConclusion: Reject the null hypothesis — At least one group mean is significantly different.")
else:
    print("\nConclusion: Fail to reject the null hypothesis — No significant difference among group means.")
# Out:
# Group A Mean: 87.2
# Group B Mean: 77.2
# Group C Mean: 92.2
#
# F-statistic: 66.7939
# P-value: 0.0
#
# Conclusion: Reject the null hypothesis — At least one group mean is significantly different.

# %% [markdown]
# Q18 Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

# Step 1: Simulated data for three groups (e.g., test scores of students taught with different methods)
group_A = [85, 90, 88, 86, 87]
group_B = [78, 75, 80, 77, 76]
group_C = [92, 94, 89, 91, 95]

# Step 2: Create a DataFrame for easier plotting
data = {
    'Score': group_A + group_B + group_C,
    'Group': (['A'] * len(group_A)) + (['B'] * len(group_B)) + (['C'] * len(group_C))
}
df = pd.DataFrame(data)

# Step 3: Perform One-Way ANOVA
f_stat, p_value = f_oneway(group_A, group_B, group_C)

# Step 4: Print results
print("Group A Mean:", np.mean(group_A))
print("Group B Mean:", np.mean(group_B))
print("Group C Mean:", np.mean(group_C))
print("\nF-statistic:", round(f_stat, 4))
print("P-value:", round(p_value, 4))

# Step 5: Interpret the result
alpha = 0.05
if p_value < alpha:
    print("\nConclusion: Reject the null hypothesis — At least one group mean is significantly different.")
else:
    print("\nConclusion: Fail to reject the null hypothesis — No significant difference among group means.")

# Step 6: Visualization — Boxplot to show group distributions
plt.figure(figsize=(8, 6))
df.boxplot(by='Group', column='Score', grid=False, patch_artist=True,
           boxprops=dict(facecolor='lightblue', color='blue'),
           medianprops=dict(color='red'))

plt.title('One-Way ANOVA: Group Score Comparison')
plt.suptitle('')
plt.xlabel('Group')
plt.ylabel('Score')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Group A Mean: 87.2
# Group B Mean: 77.2
# Group C Mean: 92.2
#
# F-statistic: 66.7939
# P-value: 0.0
#
# Conclusion: Reject the null hypothesis — At least one group mean is significantly different.

# %% [markdown]
# Q19 Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA

# %%
import numpy as np
import pandas as pd
from scipy.stats import shapiro, levene

def check_anova_assumptions(groups, group_names=None, alpha=0.05):
    """
    Check ANOVA assumptions: normality (Shapiro-Wilk) and equal variances (Levene's test).
    
    Parameters:
    - groups: list of lists or numpy arrays (e.g., [group1, group2, group3])
    - group_names: optional list of group names (e.g., ["Group A", "Group B"])
    - alpha: significance level for tests (default is 0.05)
    """

    if group_names is None:
        group_names = [f"Group {i+1}" for i in range(len(groups))]

    print("\n🔍 Checking ANOVA Assumptions\n" + "-"*35)

    # ✅ 1. Normality check (Shapiro-Wilk Test)
    print("\n✅ Normality Check (Shapiro-Wilk Test):")
    for i, group in enumerate(groups):
        stat, p = shapiro(group)
        status = "✔️ Normally distributed" if p > alpha else "❌ Not normally distributed"
        print(f"{group_names[i]}: p-value = {p:.4f} → {status}")

    # ✅ 2. Equal variance check (Levene’s Test)
    print("\n✅ Homogeneity of Variance (Levene’s Test):")
    stat, p = levene(*groups)
    status = "✔️ Variances are equal" if p > alpha else "❌ Variances are significantly different"
    print(f"Levene’s test p-value = {p:.4f} → {status}")

    # ✅ 3. Independence (Not testable here)
    print("\nℹ️ Independence Assumption:")
    print("Ensure that observations are independently collected (e.g., random sampling, no overlap).")

# ----------------------------
# ✅ Example Usage
# ----------------------------

group_A = [85, 90, 88, 86, 87]
group_B = [78, 75, 80, 77, 76]
group_C = [92, 94, 89, 91, 95]

check_anova_assumptions([group_A, group_B, group_C], group_names=["Group A", "Group B", "Group C"])
# Out:
# 🔍 Checking ANOVA Assumptions
# -----------------------------------
#
# ✅ Normality Check (Shapiro-Wilk Test):
# Group A: p-value = 0.9276 → ✔️ Normally distributed
# Group B: p-value = 0.9276 → ✔️ Normally distributed
# Group C: p-value = 0.8989 → ✔️ Normally distributed
#
# ✅ Homogeneity of Variance (Levene’s Test):
# Levene’s test p-value = 0.8326 → ✔️ Variances are equal
#
# ℹ️ Independence Assumption:
# Ensure that observations are independently collected (e.g., random sampling, no overlap).

# %% [markdown]
# Q20 Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the
# results

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Step 1: Simulate sample data
data = {
    'Score': [88, 90, 93, 85, 87, 89, 78, 76, 79, 74, 73, 77],
    'Method': ['A', 'A', 'A', 'B', 'B', 'B', 'A', 'A', 'A', 'B', 'B', 'B'],
    'StudyTime': ['Short', 'Medium', 'Long', 'Short', 'Medium', 'Long',
                  'Short', 'Medium', 'Long', 'Short', 'Medium', 'Long']
}
df = pd.DataFrame(data)

# Step 2: Two-Way ANOVA (with interaction)
model = ols('Score ~ C(Method) + C(StudyTime) + C(Method):C(StudyTime)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# Step 3: Display ANOVA table
print("📊 Two-Way ANOVA Results:\n")
print(anova_table)

# Step 4: Visualize interaction with boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x='StudyTime', y='Score', hue='Method', data=df, palette="Set2")
plt.title('Interaction Between Method and Study Time on Scores')
plt.xlabel('Study Time')
plt.ylabel('Score')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 📊 Two-Way ANOVA Results:
#
#                             sum_sq   df         F    PR(>F)
# C(Method)                30.083333  1.0  0.378804  0.560849
# C(StudyTime)             26.166667  2.0  0.164743  0.851821
# C(Method):C(StudyTime)    0.166667  2.0  0.001049  0.998951
# Residual                476.500000  6.0       NaN       NaN

# %% [markdown]
# Q21  Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

def plot_f_distribution(df1, df2, alpha=0.05):
    """
    Visualize the F-distribution with critical region.
    
    Parameters:
    - df1: degrees of freedom (numerator)
    - df2: degrees of freedom (denominator)
    - alpha: significance level (default = 0.05)
    """
    x = np.linspace(0, 5, 1000)
    y = f.pdf(x, df1, df2)

    # Critical value (right-tail)
    f_critical = f.ppf(1 - alpha, df1, df2)

    # Plot
    plt.figure(figsize=(10, 6))
    plt.plot(x, y, label=f'F-distribution (df1={df1}, df2={df2})', color='blue')

    # Shade critical region
    x_crit = np.linspace(f_critical, 5, 300)
    plt.fill_between(x_crit, f.pdf(x_crit, df1, df2), color='red', alpha=0.3, label='Rejection region')

    plt.axvline(f_critical, color='red', linestyle='--', label=f'Critical Value = {f_critical:.2f}')
    plt.title("F-Distribution with Rejection Region")
    plt.xlabel("F-Statistic")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    print(f"F Critical Value at α = {alpha}: {f_critical:.4f}")

# ✅ Example usage
plot_f_distribution(df1=5, df2=20, alpha=0.05)
# Out:
# F Critical Value at α = 0.05: 2.7109

# %% [markdown]
# Q22 Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import f_oneway

# Step 1: Simulated Data (You can replace this with real data)
group_A = [85, 90, 88, 86, 87]
group_B = [78, 75, 80, 77, 76]
group_C = [92, 94, 89, 91, 95]

# Step 2: Combine into a DataFrame
df = pd.DataFrame({
    'Score': group_A + group_B + group_C,
    'Group': ['A'] * len(group_A) + ['B'] * len(group_B) + ['C'] * len(group_C)
})

# Step 3: Perform One-Way ANOVA
f_stat, p_value = f_oneway(group_A, group_B, group_C)

# Step 4: Print the results
print("📊 One-Way ANOVA Results:")
print(f"F-statistic = {f_stat:.4f}")
print(f"P-value     = {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Conclusion: Reject H₀ — At least one group mean is significantly different.")
else:
    print("Conclusion: Fail to reject H₀ — No significant difference among group means.")

# Step 5: Boxplot Visualization
plt.figure(figsize=(8, 6))
sns.boxplot(x='Group', y='Score', data=df, palette='Set3')
plt.title('One-Way ANOVA: Comparison of Group Means')
plt.xlabel('Group')
plt.ylabel('Score')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 📊 One-Way ANOVA Results:
# F-statistic = 66.7939
# P-value     = 0.0000
# Conclusion: Reject H₀ — At least one group mean is significantly different.

# %% [markdown]
# Q23 Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means

# %%
import numpy as np
from scipy.stats import ttest_1samp
import matplotlib.pyplot as plt

# Step 1: Simulate normal data
np.random.seed(42)  # For reproducibility
population_mean = 50  # Hypothesized mean
sample_size = 30
sample_data = np.random.normal(loc=52, scale=5, size=sample_size)  # Actual sample mean is 52

# Step 2: Perform one-sample t-test
t_stat, p_value = ttest_1samp(sample_data, popmean=population_mean)

# Step 3: Print results
print("Sample Mean:", round(np.mean(sample_data), 2))
print("Population Mean (H₀):", population_mean)
print("T-statistic:", round(t_stat, 4))
print("P-value:", round(p_value, 4))

alpha = 0.05
if p_value < alpha:
    print("Conclusion: Reject H₀ — Sample mean is significantly different from population mean.")
else:
    print("Conclusion: Fail to reject H₀ — No significant difference from population mean.")

# Step 4: Visualize the sample distribution
plt.figure(figsize=(8, 5))
plt.hist(sample_data, bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(population_mean, color='red', linestyle='--', label='Population Mean (H₀)')
plt.axvline(np.mean(sample_data), color='green', linestyle='--', label='Sample Mean')
plt.title('Histogram of Simulated Sample Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Sample Mean: 51.06
# Population Mean (H₀): 50
# T-statistic: 1.2893
# P-value: 0.2075
# Conclusion: Fail to reject H₀ — No significant difference from population mean.

# %% [markdown]
# Q24 Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results

# %%
import numpy as np
from scipy.stats import chi2

# Step 1: Simulate sample data
np.random.seed(42)
sample = np.random.normal(loc=50, scale=5, size=25)  # True std dev = 5
sample_variance = np.var(sample, ddof=1)
n = len(sample)

# Step 2: Hypothesized population variance
sigma_0 = 5  # Hypothesized population standard deviation
sigma_0_squared = sigma_0**2

# Step 3: Calculate Chi-square statistic
chi_square_stat = (n - 1) * sample_variance / sigma_0_squared
df = n - 1  # degrees of freedom

# Step 4: Compute critical values for two-tailed test
alpha = 0.05
chi2_lower = chi2.ppf(alpha / 2, df)
chi2_upper = chi2.ppf(1 - alpha / 2, df)

# Step 5: Print results
print("Sample Variance:", round(sample_variance, 4))
print("Hypothesized Variance:", sigma_0_squared)
print("Chi-square Statistic:", round(chi_square_stat, 4))
print(f"Chi-square Critical Values: Lower = {round(chi2_lower, 4)}, Upper = {round(chi2_upper, 4)}")

# Step 6: Decision
if chi_square_stat < chi2_lower or chi_square_stat > chi2_upper:
    print("Conclusion: ❌ Reject H₀ — Population variance is significantly different from hypothesized.")
else:
    print("Conclusion: ✅ Fail to reject H₀ — No significant difference in population variance.")
# Out:
# Sample Variance: 22.8748
# Hypothesized Variance: 25
# Chi-square Statistic: 21.9598
# Chi-square Critical Values: Lower = 12.4012, Upper = 39.3641
# Conclusion: ✅ Fail to reject H₀ — No significant difference in population variance.

# %% [markdown]
# Q25 Write a Python script to perform a Z-test for comparing proportions between two datasets or groups

# %%
import numpy as np
from statsmodels.stats.proportion import proportions_ztest

def z_test_proportions(success_a, size_a, success_b, size_b, alpha=0.05):
    """
    Performs a two-proportion Z-test and prints the result.
    
    Parameters:
    - success_a, size_a: Successes and total trials in group A
    - success_b, size_b: Successes and total trials in group B
    - alpha: Significance level (default = 0.05)
    """
    # Successes and observations
    counts = np.array([success_a, success_b])
    nobs = np.array([size_a, size_b])

    # Perform Z-test
    z_stat, p_value = proportions_ztest(count=counts, nobs=nobs)

    print("✅ Z-Test for Two Proportions")
    print(f"Group A: {success_a}/{size_a} → Proportion = {success_a/size_a:.4f}")
    print(f"Group B: {success_b}/{size_b} → Proportion = {success_b/size_b:.4f}")
    print(f"\nZ-statistic = {z_stat:.4f}")
    print(f"P-value     = {p_value:.4f}")

    # Interpretation
    if p_value < alpha:
        print(f"Conclusion: ❌ Reject H₀ — Significant difference in proportions at α = {alpha}")
    else:
        print(f"Conclusion: ✅ Fail to reject H₀ — No significant difference in proportions at α = {alpha}")

# --------------------------------------------
# ✅ Example usage
# Group A: 60 successes out of 200
# Group B: 72 successes out of 250
# --------------------------------------------
z_test_proportions(success_a=60, size_a=200, success_b=72, size_b=250, alpha=0.05)
# Out:
# ✅ Z-Test for Two Proportions
# Group A: 60/200 → Proportion = 0.3000
# Group B: 72/250 → Proportion = 0.2880
#
# Z-statistic = 0.2778
# P-value     = 0.7811
# Conclusion: ✅ Fail to reject H₀ — No significant difference in proportions at α = 0.05

# %% [markdown]
# Q26  Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

def f_test_variances(data1, data2, alpha=0.05):
    # Step 1: Calculate sample variances
    var1 = np.var(data1, ddof=1)
    var2 = np.var(data2, ddof=1)

    # Step 2: Determine which is larger to keep F > 1
    if var1 > var2:
        F = var1 / var2
        dfn = len(data1) - 1
        dfd = len(data2) - 1
    else:
        F = var2 / var1
        dfn = len(data2) - 1
        dfd = len(data1) - 1

    # Step 3: Critical values for two-tailed test
    f_critical_low = f.ppf(alpha / 2, dfn, dfd)
    f_critical_high = f.ppf(1 - alpha / 2, dfn, dfd)

    print("✅ F-Test for Equal Variances")
    print(f"Variance 1 = {var1:.4f}")
    print(f"Variance 2 = {var2:.4f}")
    print(f"F-statistic = {F:.4f}")
    print(f"Degrees of freedom: df1 = {dfn}, df2 = {dfd}")
    print(f"Critical F-values: Lower = {f_critical_low:.4f}, Upper = {f_critical_high:.4f}")

    if F < f_critical_low or F > f_critical_high:
        print(f"❌ Reject H₀ → Variances are significantly different at α = {alpha}")
    else:
        print(f"✅ Fail to reject H₀ → No significant difference in variances at α = {alpha}")

    # Step 4: Plot F-distribution and critical regions
    x = np.linspace(0, 5, 1000)
    y = f.pdf(x, dfn, dfd)

    plt.figure(figsize=(10, 5))
    plt.plot(x, y, label='F-distribution', color='blue')
    plt.axvline(F, color='green', linestyle='--', label=f'F-stat = {F:.2f}')
    plt.axvline(f_critical_low, color='red', linestyle='--', label='Critical Lower')
    plt.axvline(f_critical_high, color='red', linestyle='--', label='Critical Upper')

    # Shade critical regions
    plt.fill_between(x, 0, y, where=(x < f_critical_low) | (x > f_critical_high), color='red', alpha=0.3)
    
    plt.title("F-Test for Comparing Two Variances")
    plt.xlabel("F value")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# ------------------------------------
# ✅ Example usage
# Simulate data from normal distributions with different variances
np.random.seed(42)
group1 = np.random.normal(loc=100, scale=10, size=30)  # Std dev = 10
group2 = np.random.normal(loc=100, scale=15, size=30)  # Std dev = 15

f_test_variances(group1, group2, alpha=0.05)
# Out:
# ✅ F-Test for Equal Variances
# Variance 1 = 81.0012
# Variance 2 = 195.0640
# F-statistic = 2.4082
# Degrees of freedom: df1 = 29, df2 = 29
# Critical F-values: Lower = 0.4760, Upper = 2.1010
# ❌ Reject H₀ → Variances are significantly different at α = 0.05

# %% [markdown]
# Q27 Perform a Chi-square test for goodness of fit with simulated data and analyze the results.

# %%
import numpy as np
from scipy.stats import chisquare
import matplotlib.pyplot as plt

# Step 1: Simulate observed data
# Let's say we observe counts in 5 categories (like dice rolls)
observed = np.array([18, 22, 20, 17, 23])

# Step 2: Define expected frequencies
# Assume uniform distribution across 5 categories
expected = np.full_like(observed, fill_value=np.sum(observed) / len(observed))

# Step 3: Perform the Chi-Square Goodness-of-Fit Test
chi_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

# Step 4: Output results
print("✅ Chi-Square Goodness-of-Fit Test")
print(f"Observed Frequencies: {observed}")
print(f"Expected Frequencies: {expected}")
print(f"Chi-square Statistic = {chi_stat:.4f}")
print(f"P-value              = {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("❌ Reject H₀ — Observed distribution significantly differs from expected.")
else:
    print("✅ Fail to reject H₀ — No significant difference from expected distribution.")

# Step 5: Optional visualization
categories = [f'Cat{i+1}' for i in range(len(observed))]
x = np.arange(len(categories))

plt.figure(figsize=(8, 5))
plt.bar(x - 0.2, observed, width=0.4, label='Observed', color='skyblue')
plt.bar(x + 0.2, expected, width=0.4, label='Expected', color='orange')
plt.xticks(x, categories)
plt.title("Chi-Square Goodness-of-Fit Test: Observed vs Expected")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ✅ Chi-Square Goodness-of-Fit Test
# Observed Frequencies: [18 22 20 17 23]
# Expected Frequencies: [20 20 20 20 20]
# Chi-square Statistic = 1.3000
# P-value              = 0.8614
# ✅ Fail to reject H₀ — No significant difference from expected distribution.
